# %%
# !git status
# Out:
# On branch preprocess
# Your branch is up to date with 'origin/preprocess'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	./
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
#Add the packages and libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("/home/laura/code/Habeus-Crimpus/dt_proj/data/data.csv", delimiter = '\t')

# %%
# !pwd
# Out:
# 1762.09s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# /home/laura/code/Habeus-Crimpus/dt_proj/notebooks

# %%
df["country"].value_counts()
# Out:
# country
# US    9252
# GB    2810
# CA    1213
# AU     760
# FI     274
#       ...
# MZ       1
# DZ       1
# LR       1
# GY       1
# OM       1
# Name: count, Length: 142, dtype: int64

# %% [markdown]
# General prerequisites
#
# #👥 Duplicates
#
# (2) 🔮 Missing data
#
# (3) 🐳 Outliers
#
# Numerical columns
#
# (4) 🔢 Scaling

# %%
df.duplicated().sum()
# Out:
# 21

# %%
#Dropped duplicates and isnull
data_wo_dup = df.drop_duplicates()
data_wo_na = data_wo_dup.dropna()

# %%
#Dropped column source
df_afterremove = data_wo_na.drop("source", axis=1)

# %%
#Converted the country colum and scaled the whole dataset
df_afterremove['US_resident'] = np.where(df_afterremove["country"]== "US", 1,0)
df_final = df_afterremove.drop("country",axis=1)
scaler = StandardScaler()
df_final_scaled = scaler.fit_transform(df_final)
df_final_final = pd.DataFrame(df_final_scaled)

# %%
df_final_final
# Out:
#              0         1         2         3         4         5         6
# 0     -0.186255  0.412763  0.529501  0.419613  0.327703  0.275552 -0.433566  \
# 1     -2.266195 -1.950770  1.359641 -1.262265 -1.192735 -2.079340 -2.734900
# 2     -1.226225 -0.375081 -0.300640  1.260553 -1.952954 -2.079340  0.717101
# 3      0.853716  1.200607  0.529501  1.260553  1.087922  1.060515  0.717101
# 4     -0.186255  0.412763 -1.130780  1.260553  1.087922  1.060515 -0.433566
# ...         ...       ...       ...       ...       ...       ...       ...
# 18164 -3.306166  1.200607 -1.130780  0.419613  0.327703  1.060515 -0.433566
# 18165  0.853716  0.412763  1.359641  0.419613  1.087922  0.275552  0.717101
# 18166 -0.186255 -0.375081 -0.300640  0.419613 -1.192735 -0.509412 -0.433566
# 18167  0.853716  0.412763 -0.300640 -0.421326  0.327703  0.275552 -0.433566
# 18168 -0.186255  0.412763  0.529501  1.260553 -0.432516  0.275552 -0.433566
#
# ...

# %%
df_afterremove.head()
# Out:
#    M1  M2  M3  M4  M5  M6  M7  M8  M9  N1  ...  P2  P3  P4  P5  P6  P7  P8
# 0   4   4   4   4   4   4   4   3   4   2  ...   4   3   2   4   4   4   4  \
# 1   2   1   5   2   2   1   2   2   3   1  ...   1   1   5   4   1   5   3
# 2   3   3   3   5   1   1   5   5   3   2  ...   5   3   1   3   1   2   3
# 3   5   5   4   5   5   5   5   5   5   5  ...   1   5   2   5   5   5   1
# 4   4   4   2   5   5   5   4   1   4   3  ...   5   3   1   4   3   5   4
#
#    P9  country  US_citizen
# 0   4       GB           0
# 1   2       US           1
# 2   1       US           1
# 3   5       GB           0
# 4   1       GB           0
#
# [5 rows x 29 columns]
